# %% [markdown]
# # Step 1: Data cleaning and merge

# %%
import numpy as np
import pandas as pd
#import omdb

import matplotlib.pyplot as plt
import matplotlib.patches as mpatches

# %%
movies = pd.read_csv('data/movies.csv')
emmy = pd.read_csv('data/the_emmy_awards.csv')
oscar = pd.read_csv('data/the_oscar_award.csv')
movies_b = pd.read_csv('data/MoviesOnStreamingPlatforms.csv')
type_amazon= pd.read_csv('data/amazon_prime_titles.csv')
type_netflix = pd.read_csv('data/netflix_titles.csv')

# %%
#only load values that matches the title values from movies
all_titles_in_movies = movies['Title'].unique()

# %%
#np.where(all_titles_in_movies == 'The First King')
all_titles_in_movies.size
# Out:
# 14858

# %%
#dowload this file from https://datasets.imdbws.com/
title_info = pd.DataFrame()
chunksize = 10 ** 5
for chunk in pd.read_csv("data/title.basics.tsv", delimiter='\t', chunksize=chunksize):
    #title_info=title_info.append (chunk)
    title_info=title_info.append (chunk[chunk.originalTitle.isin(all_titles_in_movies)])

# %%
#Checking for the number of unique values for each columns. 
#note that the title column has duplicate values. 
movies.nunique(axis=0)
# Out:
# Unnamed: 0            24664
# ID                    24664
# Title                 14858
# Year                    109
# Rating                    5
# IMDb                     87
# Rotten Tomatoes          85
# Genre                    14
# Netflix                   2
# Amazon Prime Video        2
# dtype: int64

# %%
#checking for non null values to identity columns that are can be potentially removed.
#the ratings column has a high number of null values, but this column is essential for our analysis.
#so will look to fill the null values with values from other sources

movies.isnull().sum()
# Out:
# Unnamed: 0                0
# ID                        0
# Title                     0
# Year                      0
# Rating                14635
# IMDb                    420
# Rotten Tomatoes           0
# Genre                     0
# Netflix                   0
# Amazon Prime Video        0
# dtype: int64

# %%
movies.head()
# Out:
#    Unnamed: 0  ID                  Title  Year Rating IMDb Rotten Tomatoes  \
# 0           0   1  Terminator: Dark Fate  2019    18+  6.2              81
# 1           1   2             Gemini Man  2019    13+  5.7              74
# 2           2   3      Rambo: Last Blood  2019    18+  6.1              72
# 3           3   4            The Courier  2019    18+  4.9              50
# 4           4   5                  Crawl  2019    18+  6.1              79
#
#                 Genre  Netflix  Amazon Prime Video
# 0  Action & Adventure        0                   1
# 1  Action & Adventure        0                   1
# 2  Action & Adventure        0                   1
# 3  Action & Adventure        0                   1
# 4  Action & Adventure        0                   1

# %%
#identifying the duplicate title values. The number of duplicate rows match when added with the
# values of the number of titles availale. 9806+14858 = 24664
movies.loc[movies.Title.duplicated(),['ID','Title']]
# Out:
#           ID                                    Title
# 105      106         Love Live! The School Idol Movie
# 110      111  The Stolen Princess: Ruslan and Ludmila
# 132      133                       Maya the Bee Movie
# 136      137                       Ernest & Celestine
# 252      253                I'll See You in My Dreams
# ...      ...                                      ...
# 24654  24655                                  S Storm
# 24658  24659                         Hole in the Wall
# 24659  24660                               Mama's Boy
# 24661  24662                An Unremarkable Christmas
# 24663  24664                      A Very Special Drew
#
# [9806 rows x 2 columns]

# %%
#checking to see why the titles are duplicated.
#observed that the rows are duplicated to record the multiple genre the film belongs to or
#if the movie is offered in netflix and amazon. 
movies.loc[movies['Title'].str.contains('The Stolen Princess: Ruslan and Ludmila', na=False)]
# Out:
#       Unnamed: 0    ID                                    Title  Year Rating  \
# 38            38    39  The Stolen Princess: Ruslan and Ludmila  2018    NaN
# 110          110   111  The Stolen Princess: Ruslan and Ludmila  2018    NaN
# 3949        3949  3950  The Stolen Princess: Ruslan and Ludmila  2018    NaN
#
#      IMDb Rotten Tomatoes               Genre  Netflix  Amazon Prime Video
# 38    6.1              56           Animation        0                   1
# 110   6.1              56              Comedy        0                   1
# 3949  6.1              56  Action & Adventure        0                   1

# %%
#checking to see the the year range for which the titles are avaiable 
sorted(movies.Year.unique())
# Out:
# [1912,
#  1913,
#  1915,
#  1916,
#  1917,
#  1918,
#  1919,
#  1920,
#  1921,
#  1922,
#  1923,
#  1924,
#  1925,
#  1926,
#  1927,
#  1928,
#  1929,
#  1930,
#  1931,
#  1932,
#  1933,
#  1934,
#  1935,
#  1936,
#  1937,
#  1938,
#  1939,
#  1940,
#  1941,
#  1942,
#  1943,
#  1944,
#  1945,
#  1946,
#  1947,
#  1948,
#  1949,
#  1950,
#  1951,
#  1952,
#  1953,
#  1954,
#  1955,
#  1956,
#  1957,
#  1958,
#  1959,
#  1960,
#  1961,
#  1962,
#  1963,
#  1964,
#  1965,
#  1966,
#  1967,
#  1968,
#  1969,
#  1970,
#  1971,
#  1972,
#  1973,
#  1974,
#  1975,
#  1976,
#  1977,
#  1978,
#  1979,
#  1980,
#  1981,
#  1982,
#  1983,
#  1984,
#  1985,
#  1986,
#  1987,
#  1988,
#  1989,
#  1990,
#  1991,
#  1992,
#  1993,
#  1994,
#  1995,
#  1996,
#  1997,
#  1998,
#  1999,
#  2000,
#  2001,
#  2002,
#  2003,
#  2004,
#  2005,
#  2006,
#  2007,
#  2008,
#  2009,
#  2010,
#  2011,
#  2012,
#  2013,
#  2014,
#  2015,
#  2016,
#  2017,
#  2018,
#  2019,
#  2020,
#  2021]

# %%
emmy.nunique(axis=0)
# Out:
# id          21503
# year           71
# category     1333
# nominee      5627
# staff       15735
# company       247
# producer     1273
# win             2
# dtype: int64

# %%
emmy.isnull().sum()
# Out:
# id              0
# year            0
# category        0
# nominee       156
# staff          58
# company       364
# producer    13572
# win             0
# dtype: int64

# %%
emmy[emmy['company'] == 'Netflix']
# Out:
#         id  year                                           category  \
# 3        4  2019       Outstanding Character Voice-Over Performance
# 6        7  2019  Outstanding Production Design For A Narrative ...
# 7        8  2019  Outstanding Production Design For A Narrative ...
# 11      12  2019  Outstanding Production Design For A Narrative ...
# 17      18  2019  Outstanding Production Design For A Variety, R...
# ...    ...   ...                                                ...
# 4127  4128  2013        Outstanding Original Main Title Theme Music
# 4129  4130  2013        Outstanding Original Main Title Theme Music
# 4172  4173  2013  Outstanding Single-camera Picture Editing For ...
# 4177  4178  2013  Outstanding Single-Camera Picture Editing For ...
# 4242  4243  2013                 Outstanding Special Visual Effects
#
#                              nominee  \
# 3                    F Is For Family
# 6                              Ozark
# 7               The Umbrella Academy
# 11    A Series Of Unfortunate Events
# 17                         Queer Eye
# ...                              ...
# 4127                  House of Cards
# 4129                   Hemlock Grove
# 4172            Arrested Development
# 4177                  House of Cards
# 4242                   Hemlock Grove
#
#                                                   staff  company  \
# 3                    Kevin Michael Richardson, as Rosie  Netflix
# 6     Derek R. Hill, Production Designer; John Richa...  Netflix
# 7     Mark Worthington, Production Designer; Mark St...  Netflix
# 11    Bo Welch, Production Designer; Don MacAulay, A...  Netflix
# 17                    Thomas Rouse, Production Designer  Netflix
# ...                                                 ...      ...
# 4127                                        Jeff Beal,   Netflix
# 4129                                   Nathan W. Barr,   Netflix
# 4172                   Kabir Akhtar, ; A.J. Dickerson,   Netflix
# 4177                                      Kirk Baxter,   Netflix
# 4242  Chris Jones, ; Jon Massey, ; Sean Joseph Tompk...  Netflix
#
#                                                producer    win
# 3     Wild West Television in association with Gaumo...  False
# 6                                  Media Rights Capital  False
# 7                                                   UCP  False
# 11                        A Netflix Original Production  False
# 17    Scout Productions, Inc. and ITV Entertainment,...  False
# ...                                                 ...    ...
# 4127  Donen/Fincher/Roth and Trigger Street Producti...  False
# 4129  Produced by Gaumont International Television f...  False
# 4172  Produced by Imagine TV and 20th Century Fox Te...  False
# 4177  Donen/Fincher/Roth and Trigger Street Producti...  False
# 4242  Produced by Gaumont International Television f...  False
#
# [466 rows x 8 columns]

# %%
#performing checks to see the number of matches between emmy and movies. 
#movies.loc[movies['Title'].str.contains('Orange Is The New Black', na=False)]
#movies.loc[movies.originalTitle.duplicated(),['originalTitle']]
emmy.loc[((emmy['nominee'].isin(movies['Title'])) & (emmy['company'] == 'Netflix'))]
# Out:
#         id  year                                           category  \
# 23      24  2019            Outstanding Casting For A Comedy Series
# 100    101  2019  Outstanding Single-Camera Picture Editing For ...
# 193    194  2019        Outstanding Lead Actress In A Comedy Series
# 317    318  2019  Outstanding Stunt Coordination For A Comedy Se...
# 331    332  2019            Outstanding Writing For A Comedy Series
# 332    333  2019            Outstanding Writing For A Comedy Series
# 335    336  2019             Outstanding Writing For A Drama Series
# 348    349  2019          Outstanding Writing For A Variety Special
# 352    353  2019          Outstanding Writing For A Variety Special
# 377    378  2019                      Outstanding Music Supervision
# 451    452  2019                          Outstanding Comedy Series
# 475    476  2019         Outstanding Variety Special (Pre-Recorded)
# 478    479  2019         Outstanding Variety Special (Pre-Recorded)
# 481    482  2019  Outstanding Sound Editing For A Comedy Or Dram...
# 485    486  2019  Outstanding Sound Mixing For A Comedy Or Drama...
# 513    514  2019                           Outstanding Drama Series
# 559    560  2019          Outstanding Writing For A Variety Special
# 581    582  2019  Outstanding Cinematography For A Single-Camera...
# 606    607  2019                  Outstanding Contemporary Costumes
# 613    614  2019  Outstanding Production Design For A Narrative ...
# 731    732  2018  Outstanding Casting For A Limited Series, Movi...
# 753    754  2018  Outstanding Cinematography For A Limited Serie...
# 801    802  2018  Outstanding Directing For A Limited Series, Mo...
# 875    876  2018  Outstanding Hairstyling For A Limited Series O...
# 942    943  2018  Outstanding Music Composition For A Limited Se...
# 956    957  2018        Outstanding Original Main Title Theme Music
# 974    975  2018  Outstanding Supporting Actor In A Limited Seri...
# 995    996  2018  Outstanding Lead Actress In A Limited Series O...
# 1024  1025  2018  Outstanding Supporting Actress In A Limited Se...
# 1089  1090  2018                         Outstanding Limited Series
# 1181  1182  2018  Outstanding Sound Editing For A Limited Series...
# 1259  1260  2018  Outstanding Writing For A Limited Series, Movi...
# 1271  1272  2018          Outstanding Writing For A Variety Special
# 1608  1609  2017  Outstanding Music Composition for a Limited Se...
# 1774  1775  2017                        Outstanding Variety Special
# 1801  1802  2017      Outstanding Documentary or Nonfiction Special
# 1820  1821  2017        Exceptional Merit in Documentary Filmmaking
# 1933  1934  2017          Outstanding Writing for a Variety Special
# 1937  1938  2017       Outstanding Writing for a Nonfiction Program
# 2298  2299  2016                        Outstanding Music Direction
# 2527  2528  2016                       Outstanding Television Movie
# 2585  2586  2016          Outstanding Writing For A Variety Special
# 3434  3435  2014  Outstanding Cinematography For Nonfiction Prog...
# 3443  3444  2014   Outstanding Directing For Nonfiction Programming
# 3453  3454  2014      Outstanding Documentary Or Nonfiction Special
# 3542  3543  2014  Outstanding Picture Editing For Nonfiction Pro...
#
#                              nominee  \
# 23                      Russian Doll
# 100                     Russian Doll
# 193                     Russian Doll
# 317                     Russian Doll
# 331                     Russian Doll
# 332                     Russian Doll
# 335                        Bodyguard
# 348         Adam Sandler: 100% Fresh
# 352          Wanda Sykes: Not Normal
# 377                     Russian Doll
# 451                     Russian Doll
# 475           Hannah Gadsby: Nanette
# 478          Wanda Sykes: Not Normal
# 481                     Russian Doll
# 485                     Russian Doll
# 513                        Bodyguard
# 559           Hannah Gadsby: Nanette
# 581                     Russian Doll
# 606                     Russian Doll
# 613                     Russian Doll
# 731                          Godless
# 753                          Godless
# 801                          Godless
# 875                          Godless
# 942                          Godless
# 956                          Godless
# 974                          Godless
# 995                          Godless
# 1024                         Godless
# 1089                         Godless
# 1181                         Godless
# 1259                         Godless
# 1271     Patton Oswalt: Annihilation
# 1608               The White Helmets
# 1774                 Louis C.K. 2017
# 1801                     Amanda Knox
# 1820               The White Helmets
# 1933                 Louis C.K. 2017
# 1937                     Amanda Knox
# 2298         A Very Murray Christmas
# 2527         A Very Murray Christmas
# 2585  John Mulaney: The Comeback Kid
# 3434                      The Square
# 3443                      The Square
# 3453                      The Square
# 3542                      The Square
#
#                                                   staff  company  \
# 23                    Christine Kromer, CSA, Casting by  Netflix
# 100                              Laura Weinberg, Editor  Netflix
# 193                            Natasha Lyonne, as Nadia  Netflix
# 317                Christopher Place, Stunt Coordinator  Netflix
# 331   Leslye Headland, Teleplay by & Story by; Natas...  Netflix
# 332                       Allison Silverman, Written by  Netflix
# 335                            Jed Mercurio, Written by  Netflix
# 348                            Adam Sandler, Written by  Netflix
# 352                             Wanda Sykes, Written by  Netflix
# 377                      Brienne Rose, Music Supervisor  Netflix
# 451   Natasha Lyonne, Executive Producer; Leslye Hea...  Netflix
# 475   Kevin Whyte, Executive Producer; Kathleen McCa...  Netflix
# 478   Wanda Sykes, Executive Producer / Performer; P...  Netflix
# 481   Lewis Goldstein, Sound Supervisor; Alex Soto, ...  Netflix
# 485   Lewis Goldstein, Re-Recording Mixer; Thomas Ry...  Netflix
# 513   Jed Mercurio, Executive Producer; Simon Heath,...  Netflix
# 559                           Hannah Gadsby, Written by  Netflix
# 581               Chris Teague, Director of Photography  Netflix
# 606   Jennifer Rogien, Costume Designer; Charlotte S...  Netflix
# 613   Michael Bricker, Production Designer; John Cox...  Netflix
# 731   Ellen Lewis, CSA, Casting by; Rene Haynes, CSA...  Netflix
# 753             Steven Meizler, Director of Photography  Netflix
# 801                            Scott Frank, Directed by  Netflix
# 875   Geordie Sheffer, Department Head Hairstylist; ...  Netflix
# 942                      Carlos Rafael Rivera, Music by  Netflix
# 956                      Carlos Rafael Rivera, Theme by  Netflix
# 974                      Jeff Daniels, as Frank Griffin  Netflix
# 995                 Michelle Dockery, as Alice Fletcher  Netflix
# 1024                       Merritt Wever, as Mary Agnes  Netflix
# 1089  Casey Silver, Executive Producer; Steven Soder...  Netflix
# 1181  Wylie Stateman, Co-Supervising Sound Editor; E...  Netflix
# 1259                            Scott Frank, Written by  Netflix
# 1271                          Patton Oswalt, Written by  Netflix
# 1608                          Patrick Jonsson, Music by  Netflix
# 1774  Louis C.K., Executive Producer/Performer; Dave...  Netflix
# 1801  Rod Blackhurst, Produced by; Brian McGinn, Pro...  Netflix
# 1820  Joanna Natasegara, Produced by; Orlando von Ei...  Netflix
# 1933                             Louis C.K., Written by  Netflix
# 1937  Matthew Hamachek, Written by; Brian McGinn, Wr...  Netflix
# 2298                   Paul Shaffer, Music Direction by  Netflix
# 2527  Sofia Coppola, Executive Producer; Mitch Glaze...  Netflix
# 2585                           John Mulaney, Written by  Netflix
# 3434  Jehane Noujaim, Director of Photography; Muham...  Netflix
# 3443                        Jehane Noujaim, Directed by  Netflix
# 3453  Jodie Evans, Executive Producer; Lekha Singh, ...  Netflix
# 3542  Pedro Kos, Edited by; Christopher de la Torre,...  Netflix
#
#                                                producer    win
# 23    Universal Television in association with Jax M...  False
# 100   Universal Television in association with Jax M...  False
# 193   Universal Television in association with Jax M...  False
# 317   Universal Television in association with Jax M...  False
# 331   Universal Television in association with Jax M...  False
# 332   Universal Television in association with Jax M...  False
# 335                                   World Productions  False
# 348     Irwin Entertainment l Happy Madison Productions  False
# 352                                 Push It Productions  False
# 377   Universal Television in association with Jax M...  False
# 451   Universal Television in association with Jax M...  False
# 475                       A Netflix Original Production  False
# 478                                 Push It Productions  False
# 481   Universal Television in association with Jax M...  False
# 485   Universal Television in association with Jax M...  False
# 513                                   World Productions  False
# 559                       A Netflix Original Production   True
# 581   Universal Television in association with Jax M...   True
# 606   Universal Television in association with Jax M...   True
# 613   Universal Television in association with Jax M...   True
# 731                       A Netflix Original Production  False
# 753                       A Netflix Original Production  False
# 801                       A Netflix Original Production  False
# 875                       A Netflix Original Production  False
# 942                       A Netflix Original Production  False
# 956                       A Netflix Original Production   True
# 974                       A Netflix Original Production   True
# 995                       A Netflix Original Production  False
# 1024                      A Netflix Original Production   True
# 1089                      A Netflix Original Production  False
# 1181                      A Netflix Original Production  False
# 1259                      A Netflix Original Production  False
# 1271                                           Generate  False
# 1608                         Grain Media / Violet Films  False
# 1774  3 Arts Entertainment, JAX Media, Pig Newton, Inc.  False
# 1801                                  Plus Pictures ApS  False
# 1820                         Grain Media / Violet Films  False
# 1933  3 Arts Entertainment, JAX Media, Pig Newton, Inc.  False
# 1937                                  Plus Pictures ApS  False
# 2298  American Zoetrope, South Beach Productions, De...  False
# 2527  American Zoetrope, South Beach Productions, De...  False
# 2585                                Irwin Entertainment  False
# 3434                                                NaN   True
# 3443                                                NaN   True
# 3453                                                NaN  False
# 3542                                                NaN   True

# %%
movies.loc[movies['Title'].str.contains('Barry', na=False)]
# Out:
#        Unnamed: 0     ID                             Title  Year Rating IMDb  \
# 896           896    897  Sunshine Barry & the Disco Worms  2008     7+  4.6
# 2428         2428   2429               Someone Marry Barry  2014    NaN  5.8
# 2869         2869   2870  Sunshine Barry & the Disco Worms  2008     7+  4.6
# 8780         8780   8781    The Nine Lives of Marion Barry  2009     7+  7.1
# 14477       14477  14478  Sunshine Barry & the Disco Worms  2008     7+  4.6
# 15428       15428  15429  The Adventures of Barry McKenzie  1972    18+  5.7
# 18526       18526  18527   Barry Brewer: Chicago, I'm Home  2019    NaN  7.2
# 22320       22320  22321                             Barry  2016    NaN  5.8
# 22941       22941  22942           Todd Barry: Spicy Honey  2017    16+  6.8
#
#       Rotten Tomatoes        Genre  Netflix  Amazon Prime Video
# 896                27       Family        0                   1
# 2428               57       Comedy        0                   1
# 2869               27    Animation        0                   1
# 8780               34  Documentary        0                   1
# 14477              27       Comedy        0                   1
# 15428              39       Comedy        0                   1
# 18526              39       Comedy        0                   1
# 22320              66        Drama        1                   0
# 22941              41       Comedy        1                   0

# %%
show_names = emmy.loc[emmy['nominee'].isin(movies['Title']),'nominee'].unique()
#show_names = emmy['nominee'].unique()

# %%
show_names.size
# Out:
# 143

# %%
emmy.loc[~emmy['nominee'].isin(movies['Title']),'nominee'].unique()
# Out:
# array(['The Simpsons', 'Family Guy',
#        'When You Wish Upon A Pickle: A Sesame Street Special', ...,
#        'Louis McManus For His Original Design of the Emmy',
#        'KTLA for Outstanding overall achievement in 1948',
#        'Charles Mesak/Don Lee TV for Phasefader - In Recog'], dtype=object)

# %%
movies.loc[movies['Title'].str.contains('Family Guy', na=False)]
# Out:
# Empty DataFrame
# Columns: [Unnamed: 0, ID, Title, Year, Rating, IMDb, Rotten Tomatoes, Genre, Netflix, Amazon Prime Video]
# Index: []

# %%
movies_b.loc[movies_b['Title'].str.contains('Family Guy', na=False)]
# Out:
# Empty DataFrame
# Columns: [Unnamed: 0, ID, Title, Year, Age, Rotten Tomatoes, Netflix, Hulu, Prime Video, Disney+, Type]
# Index: []

# %%
#Checking here to see if the second movie dataset that we identified has more matches with the emmy.
#its about the same. Out of 5627 titles, there are only about 140 titles for there is a match in emmy dataset
#see below the number of titles that do not have a match with the second movie dataset
emmy.loc[~emmy['nominee'].isin(movies_b['Title']),'nominee'].unique().size
# Out:
# 5530

# %%
emmy.loc[~emmy['nominee'].isin(movies['Title']),'nominee'].unique().size
# Out:
# 5485

# %%
oscar.nunique(axis=0)
# Out:
# year_film          92
# year_ceremony      92
# ceremony           92
# category          111
# name             6666
# film             4833
# winner              2
# dtype: int64

# %%
oscar.isnull().sum()
# Out:
# year_film          0
# year_ceremony      0
# ceremony           0
# category           0
# name               0
# film             304
# winner             0
# dtype: int64

# %%
#Title mismatches (out of 4833) with the old movies dataset
oscar.loc[~oscar['film'].isin(movies['Title']),'film'].unique().size
# Out:
# 4389

# %%
#Title mismatches with the new movies dataset
oscar.loc[~oscar['film'].isin(movies_b['Title']),'film'].unique().size
# Out:
# 4285

# %%
#oscar.loc[oscar['film'] =='Terminator: Dark Fate']
oscar.loc[oscar['film'].str.contains('Terminator', na=False)]
# Out:
#       year_film  year_ceremony  ceremony               category  \
# 7025       1991           1992        64         CINEMATOGRAPHY
# 7050       1991           1992        64           FILM EDITING
# 7059       1991           1992        64                 MAKEUP
# 7085       1991           1992        64                  SOUND
# 7088       1991           1992        64  SOUND EFFECTS EDITING
# 7091       1991           1992        64         VISUAL EFFECTS
#
#                                                    name  \
# 7025                                     Adam Greenberg
# 7050     Conrad Buff, Mark Goldblatt, Richard A. Harris
# 7059                            Stan Winston, Jeff Dawn
# 7085  Tom Johnson, Gary Rydstrom, Gary Summers, Lee ...
# 7088                   Gary Rydstrom, Gloria S. Borders
# 7091  Dennis Muren, Stan Winston, Gene Warren, Jr., ...
#
#                             film  winner
# 7025  Terminator 2: Judgment Day   False
# 7050  Terminator 2: Judgment Day   False
# 7059  Terminator 2: Judgment Day    True
# 7085  Terminator 2: Judgment Day    True
# 7088  Terminator 2: Judgment Day    True
# 7091  Terminator 2: Judgment Day    True

# %%
#problem? what does the movie database have? What does popular mean?
#movies.loc[movies['Title'] =='Terminator: Judgment Day']
movies.loc[movies['Title'].str.contains('Terminator', na=False)]
# Out:
#    Unnamed: 0  ID                  Title  Year Rating IMDb Rotten Tomatoes  \
# 0           0   1  Terminator: Dark Fate  2019    18+  6.2              81
#
#                 Genre  Netflix  Amazon Prime Video
# 0  Action & Adventure        0                   1

# %%
#performing checks on unique values. note that the title fields have duplicates
title_info.nunique(axis=0)
# Out:
# tconst            112356
# titleType             10
# primaryTitle       13151
# originalTitle      12673
# isAdult                4
# startYear            205
# endYear               76
# runtimeMinutes       284
# genres              1302
# dtype: int64

# %%
title_info.isnull().sum()
# Out:
# tconst            0
# titleType         0
# primaryTitle      0
# originalTitle     0
# isAdult           0
# startYear         0
# endYear           0
# runtimeMinutes    0
# genres            0
# dtype: int64

# %%
title_info.head()
# Out:
#         tconst titleType                primaryTitle  \
# 178  tt0000181     short                  Cinderella
# 305  tt0000308     short   The House That Jack Built
# 359  tt0000363     short               Magical Sword
# 395  tt0000399     short      Jack and the Beanstalk
# 561  tt0000565     short  The Night Before Christmas
#
#                   originalTitle isAdult startYear endYear runtimeMinutes  \
# 178                  Cinderella       0      1898      \N             \N
# 305   The House That Jack Built       0      1900      \N              1
# 359             The Magic Sword       0      1901      \N              2
# 395      Jack and the Beanstalk       0      1902      \N             10
# 561  The Night Before Christmas       0      1905      \N              9
#
#                        genres
# 178             Fantasy,Short
# 305                     Short
# 359     Fantasy,Romance,Short
# 395             Fantasy,Short
# 561  Animation,Family,Fantasy

# %%
title_info[(title_info['originalTitle'] == 'Cinderella') &(title_info['startYear'] == '1965')]
#.groupby(['titleType','startYear']).count()
# Out:
#              tconst titleType primaryTitle originalTitle isAdult startYear  \
# 2712508  tt13154228   tvMovie   Cinderella    Cinderella       0      1965
#
#         endYear runtimeMinutes   genres
# 2712508      \N            120  Musical

# %%
movies[movies['Title'] == 'Cinderella']
# Out:
#      Unnamed: 0   ID       Title  Year Rating IMDb Rotten Tomatoes   Genre  \
# 884         884  885  Cinderella  1965    all  7.8              57  Family
#
#      Netflix  Amazon Prime Video
# 884        0                   1

# %%
title_info.info(verbose=True)
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 112356 entries, 178 to 8541347
# Data columns (total 9 columns):
# tconst            112356 non-null object
# titleType         112356 non-null object
# primaryTitle      112356 non-null object
# originalTitle     112356 non-null object
# isAdult           112356 non-null object
# startYear         112356 non-null object
# endYear           112356 non-null object
# runtimeMinutes    112356 non-null object
# genres            112356 non-null object
# dtypes: object(9)
# memory usage: 8.6+ MB

# %%
#remove titles before the year 1912. Replace first \N with nan value
title_info = title_info.replace('\\N',np.NaN)
title_info.head()
# Out:
#         tconst titleType                primaryTitle  \
# 178  tt0000181     short                  Cinderella
# 305  tt0000308     short   The House That Jack Built
# 359  tt0000363     short               Magical Sword
# 395  tt0000399     short      Jack and the Beanstalk
# 561  tt0000565     short  The Night Before Christmas
#
#                   originalTitle isAdult startYear endYear runtimeMinutes  \
# 178                  Cinderella       0      1898     NaN            NaN
# 305   The House That Jack Built       0      1900     NaN              1
# 359             The Magic Sword       0      1901     NaN              2
# 395      Jack and the Beanstalk       0      1902     NaN             10
# 561  The Night Before Christmas       0      1905     NaN              9
#
#                        genres
# 178             Fantasy,Short
# 305                     Short
# 359     Fantasy,Romance,Short
# 395             Fantasy,Short
# 561  Animation,Family,Fantasy

# %%
#Remove entries for years less than 1912, genres that are talkshows, and titles that are short, videos and tvspecials
#also removed tvepisode since they didn't seem relevent for our analysis. 
title_info_clean = title_info[((title_info['startYear'].astype(np.float)>=1912) 
                               & (title_info['genres'].str.contains('Talk-Show') == False)
                               & (title_info['titleType'].isin(['short','video','tvShort','tvEpisode', 'tvSpecial', 'tvMiniSeries', 'videoGame']) == False)
                              )]

# %%
title_info_clean.titleType.unique()
# Out:
# array(['movie', 'tvMovie', 'tvSeries'], dtype=object)

# %%
movies['Year'].dtypes
# Out:
# dtype('int64')

# %%
#After removing the year, the duplicates reduced from 68716 to 50444
#but if you jus check the unique values, there are about 28470
#title_info_clean.loc[title_info_clean.originalTitle.duplicated(),['originalTitle']].originalTitle.unique().size
title_info_clean.loc[title_info_clean.originalTitle.duplicated(),['originalTitle']].originalTitle.unique
# Out:
# <bound method Series.unique of 2379                Oliver Twist
# 5859       The Prisoner of Zenda
# 6908                     Macbeth
# 7051                Oliver Twist
# 7360        The Three Musketeers
#                    ...
# 8529332                 The Line
# 8535270               The System
# 8535495              Good Enough
# 8537956               Blown Away
# 8540312                 Paradise
# Name: originalTitle, Length: 11590, dtype: object>

# %%
#I checked a couple of them and it the duplicates seem to be legitimate (Oliver Twist for example)
#The other point is that the movies database doesn't seem to be comprehesive enough. 
#also remove entries which are talk shows. 
#Strange that some of the movies are not in this file downloaded from IMDB: Along with the Gods: The Two Worlds, The First King 
#Though you can find IMDB ratings for them when you search for the movie names. 
title_info.loc[title_info['originalTitle'].str.contains('I Am Jonas', na=False)]
#title_info_clean.loc[title_info_clean['originalTitle'].str.contains('Along with the Gods: The Two Worlds', na=False)]
#title_info_clean.loc[((title_info_clean['originalTitle'].str.contains('Kill Chain', na=False)) & (title_info_clean['startYear'] == '2019'))]
#movies.loc[movies['Title'].str.contains('Oliver Twist', na=False)]
# Out:
# Empty DataFrame
# Columns: [tconst, titleType, primaryTitle, originalTitle, isAdult, startYear, endYear, runtimeMinutes, genres]
# Index: []

# %%
title_info[['titleType','genres']].groupby(['titleType','genres']).head()
# Out:
#             titleType                      genres
# 178             short               Fantasy,Short
# 305             short                       Short
# 359             short       Fantasy,Romance,Short
# 395             short               Fantasy,Short
# 561             short    Animation,Family,Fantasy
# ...               ...                         ...
# 8510823     tvEpisode  Drama,Game-Show,Reality-TV
# 8522988         short            Action,Short,War
# 8527924       tvShort    Documentary,Family,Short
# 8535898  tvMiniSeries           Documentary,Music
# 8537912  tvMiniSeries                 Drama,Short
#
# [9974 rows x 2 columns]

# %%
movie_names = oscar.loc[oscar['film'].isin(movies['Title']),'film'].unique()

# %%
movie_names.size
# Out:
# 445

# %%
movies['type'] = np.nan

# %%
#adding the type column
movies.loc[movies['Title'].isin(show_names), 'type'] = 'shows'
movies.loc[movies['Title'].isin(movie_names), 'type'] = 'movie'

# %%
movies.head(100)
# Out:
#     Unnamed: 0   ID                                       Title  Year Rating  \
# 0            0    1                       Terminator: Dark Fate  2019    18+
# 1            1    2                                  Gemini Man  2019    13+
# 2            2    3                           Rambo: Last Blood  2019    18+
# 3            3    4                                 The Courier  2019    18+
# 4            4    5                                       Crawl  2019    18+
# ..         ...  ...                                         ...   ...    ...
# 95          95   96                Scott Walker: 30 Century Man  2007    all
# 96          96   97                          The Real Bruce Lee  1977    NaN
# 97          97   98             Drew: The Man Behind the Poster  2013    NaN
# 98          98   99                     Lauda: The Untold Story  2015    NaN
# 99          99  100  Pantani: The Accidental Death of a Cyclist  2014     7+
#
#    IMDb Rotten Tomatoes               Genre  Netflix  Amazon Prime Video type
# 0   6.2              81  Action & Adventure        0                   1  NaN
# 1   5.7              74  Action & Adventure        0                   1  NaN
# 2   6.1              72  Action & Adventure        0                   1  NaN
# 3   4.9              50  Action & Adventure        0                   1  NaN
# 4   6.1              79  Action & Adventure        0                   1  NaN
# ..  ...             ...                 ...      ...                 ...  ...
# 95  7.2              62           Biography        0                   1  NaN
# 96  4.7              38           Biography        0                   1  NaN
# 97  7.5              59           Biography        0                   1  NaN
# 98  6.4              41           Biography        0                   1  NaN
# 99  7.0              63           Biography        0                   1  NaN
#
# [100 rows x 11 columns]

# %%
movie_names_null = movies.loc[movies['type'].isnull(),'Title']

# %%
#since there are duplicate movie names with some being movies and other shows. Take the example of Oliver Twist above. 
#To exactly match the type, we also need to match the year of the movie/shows

title_info_clean_small = title_info_clean[['titleType','originalTitle','startYear']]
title_info_clean_small = title_info_clean_small[title_info_clean_small['originalTitle'].isin(movie_names_null)]
title_info_clean_small = title_info_clean_small.drop_duplicates(
  subset = ['originalTitle', 'startYear','titleType']).reset_index(drop = True)
title_info_clean_small = title_info_clean_small.rename(columns={"originalTitle": "Title","titleType":"type","startYear":"Year"})

# %%
title= 'Terminator: Dark Fate'
year = 2019
title_info_clean.loc[((title_info_clean['originalTitle']== title) & (title_info_clean['startYear'].astype(int) == year)),'titleType']
# Out:
# 6951218    movie
# Name: titleType, dtype: object

# %%
title= 'Danger Close'
year = 2019

stype = title_info_clean_small.loc[((title_info_clean_small['Title']== title) & (title_info_clean_small['Year'].astype(int) == year)),'type']
#stype = title_info_clean.loc[((title_info_clean['originalTitle']== title) & (title_info_clean['startYear'] == year)),'titleType']
# stype = type_amazon.loc[((type_amazon['title']== title) & (type_amazon['release_year'].astype(int) == year)),'type']
# print(stype)
if(stype.empty == False):
    print(stype.values.size)
    print(title + ": count -" + str(stype.values.size) + str(stype.values[0]))
elif((type_amazon.loc[((type_amazon['title']== title) & (type_amazon['release_year'].astype(int) == year)),'type']).empty == False):
    stype = type_amazon.loc[((type_amazon['title']== title)),'type']
    print(stype.values[0].lower())
elif((type_netflix.loc[((type_netflix['title']== title) & (type_netflix['release_year'].astype(int) == year)),'type']).empty == False):
    stype = type_netflix.loc[((type_netflix['title']== title)),'type']
    print(stype.values[0])
else:
     print("no value")
# Out:
# movie

# %%
#movies["Type"]
def get_type(title, year,oldtype):
    stype = title_info_clean_small.loc[((title_info_clean_small['Title']== title) & (title_info_clean_small['Year'].astype(int) == year)),'type']
    #print(title)
    #print(year)
    val =""
    if(stype.empty == False):
        #if(stype.values.size > 1):
            #print(title + " " + str(year) + ": count -" + str(stype.values.size))
        val = stype.values[0]
    #not matching years for the below as in some cases there are year mismatches
    elif((type_amazon.loc[((type_amazon['title']== title)),'type']).empty == False):
        stype = type_amazon.loc[((type_amazon['title']== title)),'type']
        val= stype.values[0].lower()
    elif((type_netflix.loc[((type_netflix['title']== title)),'type']).empty == False):
        stype = type_netflix.loc[((type_netflix['title']== title)),'type']
        val = stype.values[0].lower()
    else:
        val = oldtype
    if(val == 'tv show'):
        val = "shows"
    return val
movies['type']= movies.apply(lambda x: get_type(x.Title, x.Year, x.type), axis=1)

# %%
#prior to mapping with IMDB database, the null type values were 23687
movies.isnull().sum()
# Out:
# Unnamed: 0                0
# ID                        0
# Title                     0
# Year                      0
# Rating                14635
# IMDb                    420
# Rotten Tomatoes           0
# Genre                     0
# Netflix                   0
# Amazon Prime Video        0
# type                   6012
# dtype: int64

# %%
#271304
movies.size
# Out:
# 271304

# %%
#These movie don't seem to be a match in any of the other files. 
movies[movies['type'].isnull() == True]
# Out:
#        Unnamed: 0     ID                                Title  Year Rating  \
# 23             23     24                       The First King  2019    18+
# 26             26     27  Along with the Gods: The Two Worlds  2017     7+
# 33             33     34                     Asterix the Gaul  1967    all
# 34             34     35  SlugTerra: Return of the Elementals  2014     7+
# 35             35     36               Ooops! Noah is Gone...  2015    all
# ...           ...    ...                                  ...   ...    ...
# 24609       24609  24610                   Sometimes it rains  2016    NaN
# 24637       24637  24638                     Kaviyude Osyathu  2017    NaN
# 24640       24640  24641                     Beirut oh Beirut  1975    NaN
# 24660       24660  24661                           I Am Jonas  2018    NaN
# 24663       24663  24664                  A Very Special Drew  2000    NaN
#
#       IMDb Rotten Tomatoes               Genre  Netflix  Amazon Prime Video  \
# 23     6.5              54  Action & Adventure        0                   1
# 26     7.3              73  Action & Adventure        0                   1
# 33     6.6              53           Animation        0                   1
# 34     6.4              48           Animation        0                   1
# 35     5.8              57           Animation        0                   1
# ...    ...             ...                 ...      ...                 ...
# 24609  NaN              13               Drama        1                   0
# 24637  3.8              25               Drama        1                   0
# 24640  6.7              38               Drama        1                   0
# 24660  7.0              52               Drama        1                   0
# 24663  8.0              41               Drama        1                   0
#
#       type
# 23     NaN
# 26     NaN
# 33     NaN
# 34     NaN
# 35     NaN
# ...    ...
# 24609  NaN
# 24637  NaN
# 24640  NaN
# 24660  NaN
# 24663  NaN
#
# [6012 rows x 11 columns]

# %%
#don't think there needs to be a distinction between movie and TV movie, so setting all tvmovie to movie
movies[movies['type'] == "tvMovie"]
# Out:
#        Unnamed: 0     ID                                Title  Year Rating  \
# 25             25     26  The Last Sharknado: It's About Time  2018    16+
# 146           146    147                               Python  2000    18+
# 154           154    155                   An Inspector Calls  2015     7+
# 224           224    225                          Monsterwolf  2010    18+
# 291           291    292               Stalked by My Neighbor  2015    16+
# ...           ...    ...                                  ...   ...    ...
# 24186       24186  24187                       The Laundromat  1985    18+
# 24364       24364  24365                                Rabun  2003    NaN
# 24439       24439  24440                       Bye Bye London  1982    NaN
# 24474       24474  24475                       The Laundromat  1985    18+
# 24498       24498  24499             Adam: His Song Continues  1986    NaN
#
#       IMDb Rotten Tomatoes               Genre  Netflix  Amazon Prime Video  \
# 25     3.5              47  Action & Adventure        0                   1
# 146    3.7              31              Comedy        0                   1
# 154    7.7              66               Crime        0                   1
# 224    3.6              32         Documentary        0                   1
# 291    5.2              40               Drama        0                   1
# ...    ...             ...                 ...      ...                 ...
# 24186  7.5              45              Comedy        1                   0
# 24364  8.0              40               Drama        1                   0
# 24439  9.0              49               Drama        1                   0
# 24474  7.5              45               Drama        1                   0
# 24498  7.2              40               Drama        1                   0
#
#           type
# 25     tvMovie
# 146    tvMovie
# 154    tvMovie
# 224    tvMovie
# 291    tvMovie
# ...        ...
# 24186  tvMovie
# 24364  tvMovie
# 24439  tvMovie
# 24474  tvMovie
# 24498  tvMovie
#
# [1103 rows x 11 columns]

# %%
movies['type'].loc[(movies['type'] == "tvMovie")]= 'movie'
movies['type'].loc[(movies['type'] == "tvSeries")]= 'shows'

# %%
movies.type.unique()
# Out:
# array(['movie', 'shows', nan], dtype=object)

# %%
movies[movies['Amazon Prime Video']==1].groupby(['Amazon Prime Video','type']).agg('count')
# Out:
#                           Unnamed: 0     ID  Title   Year  Rating   IMDb  \
# Amazon Prime Video type
# 1                  movie       14857  14857  14857  14857    6052  14695
#                    shows         236    236    236    236     105    230
#
#                           Rotten Tomatoes  Genre  Netflix
# Amazon Prime Video type
# 1                  movie            14857  14857    14857
#                    shows              236    236      236

# %%
movies[movies['Netflix']==1].groupby(['Netflix','type']).agg('count')
# Out:
#                Unnamed: 0    ID  Title  Year  Rating  IMDb  Rotten Tomatoes  \
# Netflix type
# 1       movie        3516  3516   3516  3516    1758  3478             3516
#         shows          43    43     43    43      20    41               43
#
#                Genre  Amazon Prime Video
# Netflix type
# 1       movie   3516                3516
#         shows     43                  43

# %%
movies_b.nunique(axis=0)
# Out:
# Unnamed: 0         9515
# ID                 9515
# Title              9515
# Year                103
# Age                   5
# Rotten Tomatoes      85
# Netflix               2
# Hulu                  2
# Prime Video           2
# Disney+               2
# Type                  1
# dtype: int64

# %%
movies_b.head()
# Out:
#    Unnamed: 0  ID                                     Title  Year  Age  \
# 0           0   1                              The Irishman  2019  18+
# 1           1   2                                    Dangal  2016   7+
# 2           2   3  David Attenborough: A Life on Our Planet  2020   7+
# 3           3   4         Lagaan: Once Upon a Time in India  2001   7+
# 4           4   5                                      Roma  2018  18+
#
#   Rotten Tomatoes  Netflix  Hulu  Prime Video  Disney+  Type
# 0          98/100        1     0            0        0     0
# 1          97/100        1     0            0        0     0
# 2          95/100        1     0            0        0     0
# 3          94/100        1     0            0        0     0
# 4          94/100        1     0            0        0     0

# %%
movies_b.groupby(['Netflix','Prime Video']).agg('count')
# Out:
#                      Unnamed: 0    ID  Title  Year   Age  Rotten Tomatoes  \
# Netflix Prime Video
# 0       0                  1816  1816   1816  1816  1341             1816
#         1                  4004  4004   4004  4004  2099             4004
# 1       0                  3586  3586   3586  3586  1832             3579
#         1                   109   109    109   109    66              109
#
#                      Hulu  Disney+  Type
# Netflix Prime Video
# 0       0            1816     1816  1816
#         1            4004     4004  4004
# 1       0            3586     3586  3586
#         1             109      109   109

# %%
movies_b.Year.unique()
# Out:
# array([2019, 2016, 2020, 2001, 2018, 2017, 2004, 2014, 2015, 2006, 1991,
#        2012, 2010, 2011, 2013, 2005, 1998, 2002, 2009, 1971, 2003, 2007,
#        1975, 1988, 2008, 1974, 1979, 1997, 1990, 2021, 1984, 2000, 1993,
#        1994, 1999, 1976, 1964, 1954, 1982, 1986, 1992, 1995, 1987, 1989,
#        1980, 1996, 1958, 1981, 1977, 1983, 1970, 1963, 1985, 1972, 1962,
#        1966, 1956, 1969, 1973, 1960, 1959, 1978, 1968, 1940, 1941, 1965,
#        1923, 1950, 1953, 1957, 1955, 1946, 1936, 1952, 1967, 1935, 1951,
#        1925, 1947, 1945, 1948, 1939, 1942, 1932, 1937, 1919, 1949, 1934,
#        1931, 1922, 1927, 1933, 1920, 1961, 1944, 1943, 1915, 1929, 1938,
#        1914, 1930, 1928, 1916])

# %%
#Titles that are not in the the first movie dataset
movies_b.loc[~movies_b['Title'].isin(movies['Title'])]
# Out:
#       Unnamed: 0    ID                                     Title  Year  Age  \
# 0              0     1                              The Irishman  2019  18+
# 2              2     3  David Attenborough: A Life on Our Planet  2020   7+
# 5              5     6         To All the Boys I've Loved Before  2018  13+
# 6              6     7                        The Social Dilemma  2020  13+
# 8              8     9              The Ballad of Buster Scruggs  2018  16+
# ...          ...   ...                                       ...   ...  ...
# 9510        9510  9511                        Most Wanted Sharks  2020  NaN
# 9511        9511  9512             Doc McStuffins: The Doc Is In  2020  NaN
# 9512        9512  9513                     Ultimate Viking Sword  2019  NaN
# 9513        9513  9514           Hunt for the Abominable Snowman  2011  NaN
# 9514        9514  9515       Women of Impact: Changing the World  2019   7+
#
#      Rotten Tomatoes  Netflix  Hulu  Prime Video  Disney+  Type
# 0             98/100        1     0            0        0     0
# 2             95/100        1     0            0        0     0
# 5             94/100        1     0            0        0     0
# 6             93/100        1     0            0        0     0
# 8             92/100        1     0            0        0     0
# ...              ...      ...   ...          ...      ...   ...
# 9510          14/100        0     0            0        1     0
# 9511          13/100        0     0            0        1     0
# 9512          13/100        0     0            0        1     0
# 9513          10/100        0     0            0        1     0
# 9514          10/100        0     0            0        1     0
#
# [4606 rows x 11 columns]

# %%
#Next steps
#Movies master database: Fill gaps in Type, Rating; nominated (boolean)/ no.of nominations/ no. of winners
#Oscar and the emmy: 
### number of awards won for each show/movie; 
#? prep for analysis
#sub dataframes or files (aggregtes over time - production year and the years in award files)
